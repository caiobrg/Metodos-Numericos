# %%
import polars as pl

df = pl.read_csv("outputs/fractal_pol_7.csv")

df.filter(pl.col("exact_root") == 1)
# Out:
# shape: (9, 7)
# ┌──────┬──────┬───────────┬─────────┬────────┬────────┬────────────┐
# │ r    ┆ s    ┆ iteracoes ┆ sucesso ┆ r_conv ┆ s_conv ┆ exact_root │
# │ ---  ┆ ---  ┆ ---       ┆ ---     ┆ ---    ┆ ---    ┆ ---        │
# │ f64  ┆ f64  ┆ i64       ┆ i64     ┆ i64    ┆ i64    ┆ i64        │
# ╞══════╪══════╪═══════════╪═════════╪════════╪════════╪════════════╡
# │ -5.0 ┆ 6.0  ┆ 18        ┆ 1       ┆ -5     ┆ 6      ┆ 1          │
# │ 6.0  ┆ -5.0 ┆ 23        ┆ 1       ┆ 6      ┆ -5     ┆ 1          │
# │ 1.0  ┆ 6.0  ┆ 8         ┆ 1       ┆ 1      ┆ 6      ┆ 1          │
# │ -3.0 ┆ 4.0  ┆ 13        ┆ 1       ┆ -3     ┆ 4      ┆ 1          │
# │ 8.0  ┆ -7.0 ┆ 13        ┆ 1       ┆ 8      ┆ -7     ┆ 1          │
# │ 3.0  ┆ 10.0 ┆ 17        ┆ 1       ┆ 3      ┆ 10     ┆ 1          │
# │ 4.0  ┆ -3.0 ┆ 9         ┆ 1       ┆ 4      ┆ -3     ┆ 1          │
# │ -1.0 ┆ 2.0  ┆ 8         ┆ 1       ┆ -1     ┆ 2      ┆ 1          │
# ...
